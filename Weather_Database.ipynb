# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config_gmaps import g_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['pevek', 'port lincoln', 'vaini', 'necochea', 'ushuaia', 'bhakkar', 'busselton', 'klaksvik', 'hermanus', 'hithadhoo'] Generate 765

# %%
# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    
    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | necochea
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | bhakkar
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | klaksvik
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | muros
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | nemuro
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | umm lajj
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | havoysund
# Processing Record 18 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 1 | sur
# Processing Record 20 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | verkhnevilyuysk
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | san quintin
# Processing Record 29 of Set 1 | suntar
# Processing Record 30 of Set 1 | sao filipe
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | coquimbo
# Processing Record 38 of Set 1 | lovozero
# Processing Record 39 of Set 1 | kropotkin
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | toropets
# Processing Record 45 of Set 1 | san jeronimo
# Processing Record 46 of Set 1 | aquiraz
# Processing Record 47 of Set 1 | trat
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | faya
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | bhadrak
# Processing Record 4 of Set 2 | bellefontaine
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | dingle
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | djibo
# Processing Record 9 of Set 2 | mirnyy
# Processing Record 10 of Set 2 | mehamn
# Processing Record 11 of Set 2 | flinders
# Processing Record 12 of Set 2 | semnan
# Processing Record 13 of Set 2 | ormara
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | fairbanks
# Processing Record 16 of Set 2 | batemans bay
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | shitanjing
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | zorritos
# Processing Record 21 of Set 2 | ternate
# Processing Record 22 of Set 2 | alice springs
# Processing Record 23 of Set 2 | bonthe
# Processing Record 24 of Set 2 | torbay
# Processing Record 25 of Set 2 | batagay
# Processing Record 26 of Set 2 | hofn
# Processing Record 27 of Set 2 | neustrelitz
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | wuda
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | nome
# Processing Record 39 of Set 2 | noumea
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | victor harbor
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | lapa
# Processing Record 44 of Set 2 | uige
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 2 | bijie
# Processing Record 48 of Set 2 | kruisfontein
# Processing Record 49 of Set 2 | faanui
# Processing Record 50 of Set 2 | muzhi
# Processing Record 1 of Set 3 | diffa
# Processing Record 2 of Set 3 | ust-kishert
# Processing Record 3 of Set 3 | caceres
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | mataura
# Processing Record 6 of Set 3 | sorong
# Processing Record 7 of Set 3 | changji
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | nantucket
# Processing Record 10 of Set 3 | kerrville
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | kaohsiung
# Processing Record 13 of Set 3 | nenjiang
# Processing Record 14 of Set 3 | elko
# Processing Record 15 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 3 | siocon
# Processing Record 17 of Set 3 | buin
# Processing Record 18 of Set 3 | el reno
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | leningradskiy
# Processing Record 21 of Set 3 | paamiut
# Processing Record 22 of Set 3 | gilgit
# Processing Record 23 of Set 3 | haines junction
# Processing Record 24 of Set 3 | matagami
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | morristown
# Processing Record 27 of Set 3 | jaisalmer
# Processing Record 28 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | saint-philippe
# Processing Record 31 of Set 3 | new norfolk
# Processing Record 32 of Set 3 | ust-nera
# Processing Record 33 of Set 3 | vanimo
# Processing Record 34 of Set 3 | neiafu
# Processing Record 35 of Set 3 | kyren
# Processing Record 36 of Set 3 | gari
# Processing Record 37 of Set 3 | comodoro rivadavia
# Processing Record 38 of Set 3 | independence
# Processing Record 39 of Set 3 | asau
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 3 | tuatapere
# Processing Record 43 of Set 3 | ak-dovurak
# Processing Record 44 of Set 3 | grimari
# City not found. Skipping...
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | zhigansk
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | butaritari
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | homnabad
# Processing Record 1 of Set 4 | kismayo
# Processing Record 2 of Set 4 | saint-augustin
# Processing Record 3 of Set 4 | san pedro
# Processing Record 4 of Set 4 | hervey bay
# Processing Record 5 of Set 4 | kailua
# Processing Record 6 of Set 4 | san cristobal
# Processing Record 7 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 8 of Set 4 | madang
# Processing Record 9 of Set 4 | half moon bay
# Processing Record 10 of Set 4 | los llanos de aridane
# Processing Record 11 of Set 4 | marrakesh
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | halifax
# Processing Record 14 of Set 4 | valparaiso
# Processing Record 15 of Set 4 | huarmey
# Processing Record 16 of Set 4 | sipe sipe
# Processing Record 17 of Set 4 | yellowknife
# Processing Record 18 of Set 4 | namatanai
# Processing Record 19 of Set 4 | geraldton
# Processing Record 20 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 4 | luanda
# Processing Record 22 of Set 4 | bengkulu
# Processing Record 23 of Set 4 | qui nhon
# Processing Record 24 of Set 4 | subaytilah
# City not found. Skipping...
# Processing Record 25 of Set 4 | maloy
# Processing Record 26 of Set 4 | okha
# Processing Record 27 of Set 4 | shumskiy
# Processing Record 28 of Set 4 | lagoa
# Processing Record 29 of Set 4 | ekimchan
# Processing Record 30 of Set 4 | vilyuysk
# Processing Record 31 of Set 4 | bandarbeyla
# Processing Record 32 of Set 4 | maracaibo
# Processing Record 33 of Set 4 | meulaboh
# Processing Record 34 of Set 4 | gboko
# Processing Record 35 of Set 4 | russell
# Processing Record 36 of Set 4 | bichura
# Processing Record 37 of Set 4 | esfahan
# Processing Record 38 of Set 4 | tiksi
# Processing Record 39 of Set 4 | sembakung
# Processing Record 40 of Set 4 | cayenne
# Processing Record 41 of Set 4 | gorontalo
# Processing Record 42 of Set 4 | yumen
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | la rioja
# Processing Record 45 of Set 4 | cherskiy
# Processing Record 46 of Set 4 | amahai
# Processing Record 47 of Set 4 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 48 of Set 4 | mazyr
# Processing Record 49 of Set 4 | urucara
# Processing Record 50 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 1 of Set 5 | chirilagua
# Processing Record 2 of Set 5 | saint george
# Processing Record 3 of Set 5 | dabakala
# Processing Record 4 of Set 5 | borovoy
# Processing Record 5 of Set 5 | iskateley
# Processing Record 6 of Set 5 | atherton
# Processing Record 7 of Set 5 | nanortalik
# Processing Record 8 of Set 5 | charlestown
# Processing Record 9 of Set 5 | nikolskoye
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | bilibino
# Processing Record 12 of Set 5 | platteville
# Processing Record 13 of Set 5 | sergeyevka
# Processing Record 14 of Set 5 | dauphin
# Processing Record 15 of Set 5 | port elizabeth
# Processing Record 16 of Set 5 | kuusamo
# Processing Record 17 of Set 5 | dikson
# Processing Record 18 of Set 5 | champerico
# Processing Record 19 of Set 5 | namtsy
# Processing Record 20 of Set 5 | fortuna
# Processing Record 21 of Set 5 | dovolnoye
# Processing Record 22 of Set 5 | boyolangu
# Processing Record 23 of Set 5 | henties bay
# Processing Record 24 of Set 5 | tessalit
# Processing Record 25 of Set 5 | sinnamary
# Processing Record 26 of Set 5 | hemnesberget
# Processing Record 27 of Set 5 | santa maria
# Processing Record 28 of Set 5 | alberton
# Processing Record 29 of Set 5 | matamoros
# Processing Record 30 of Set 5 | burgeo
# Processing Record 31 of Set 5 | inhambane
# Processing Record 32 of Set 5 | vostok
# Processing Record 33 of Set 5 | russkaya polyana
# Processing Record 34 of Set 5 | teshie
# Processing Record 35 of Set 5 | richards bay
# Processing Record 36 of Set 5 | saint-paul
# Processing Record 37 of Set 5 | avarua
# Processing Record 38 of Set 5 | cuamba
# Processing Record 39 of Set 5 | amnat charoen
# Processing Record 40 of Set 5 | pingxiang
# Processing Record 41 of Set 5 | lavrentiya
# Processing Record 42 of Set 5 | himora
# City not found. Skipping...
# Processing Record 43 of Set 5 | marawi
# Processing Record 44 of Set 5 | semkhoz
# Processing Record 45 of Set 5 | camana
# Processing Record 46 of Set 5 | cabedelo
# Processing Record 47 of Set 5 | binghamton
# Processing Record 48 of Set 5 | bull savanna
# Processing Record 49 of Set 5 | itarema
# Processing Record 50 of Set 5 | nara
# Processing Record 1 of Set 6 | powell river
# Processing Record 2 of Set 6 | ko samui
# Processing Record 3 of Set 6 | barra do garcas
# Processing Record 4 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 6 | touros
# Processing Record 6 of Set 6 | juegang
# Processing Record 7 of Set 6 | souillac
# Processing Record 8 of Set 6 | nabire
# Processing Record 9 of Set 6 | fremont
# Processing Record 10 of Set 6 | babstovo
# Processing Record 11 of Set 6 | yaring
# Processing Record 12 of Set 6 | mount isa
# Processing Record 13 of Set 6 | rio gallegos
# Processing Record 14 of Set 6 | jubb jannin
# City not found. Skipping...
# Processing Record 15 of Set 6 | yar-sale
# Processing Record 16 of Set 6 | adrar
# Processing Record 17 of Set 6 | hirara
# Processing Record 18 of Set 6 | sakaiminato
# Processing Record 19 of Set 6 | harpanahalli
# Processing Record 20 of Set 6 | nanakuli
# Processing Record 21 of Set 6 | prilly
# Processing Record 22 of Set 6 | saldanha
# Processing Record 23 of Set 6 | toamasina
# Processing Record 24 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 26 of Set 6 | salalah
# Processing Record 27 of Set 6 | sovetskiy
# Processing Record 28 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 6 | dryden
# Processing Record 30 of Set 6 | murray bridge
# Processing Record 31 of Set 6 | el retorno
# Processing Record 32 of Set 6 | vardo
# Processing Record 33 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 6 | cayeli
# Processing Record 35 of Set 6 | xining
# Processing Record 36 of Set 6 | college
# Processing Record 37 of Set 6 | mayumba
# Processing Record 38 of Set 6 | kavaratti
# Processing Record 39 of Set 6 | gat
# Processing Record 40 of Set 6 | kamenka
# Processing Record 41 of Set 6 | san policarpo
# Processing Record 42 of Set 6 | vestmannaeyjar
# Processing Record 43 of Set 6 | methoni
# Processing Record 44 of Set 6 | kavieng
# Processing Record 45 of Set 6 | praia da vitoria
# Processing Record 46 of Set 6 | horsham
# Processing Record 47 of Set 6 | progreso
# Processing Record 48 of Set 6 | zharkent
# Processing Record 49 of Set 6 | lorengau
# Processing Record 50 of Set 6 | carnarvon
# Processing Record 1 of Set 7 | fort nelson
# Processing Record 2 of Set 7 | qurayyat
# Processing Record 3 of Set 7 | sadowara
# City not found. Skipping...
# Processing Record 4 of Set 7 | maymyo
# Processing Record 5 of Set 7 | buchanan
# Processing Record 6 of Set 7 | tallahassee
# Processing Record 7 of Set 7 | alofi
# Processing Record 8 of Set 7 | rocha
# Processing Record 9 of Set 7 | miri
# Processing Record 10 of Set 7 | walajapet
# Processing Record 11 of Set 7 | carmen
# Processing Record 12 of Set 7 | plymouth
# Processing Record 13 of Set 7 | saurimo
# Processing Record 14 of Set 7 | pamanukan
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | nizhniy tsasuchey
# Processing Record 17 of Set 7 | berlesti
# Processing Record 18 of Set 7 | sorland
# Processing Record 19 of Set 7 | olafsvik
# Processing Record 20 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 7 | bambanglipuro
# Processing Record 22 of Set 7 | altay
# Processing Record 23 of Set 7 | hasaki
# Processing Record 24 of Set 7 | nampula
# Processing Record 25 of Set 7 | riyadh
# Processing Record 26 of Set 7 | rawson
# Processing Record 27 of Set 7 | coahuayana
# Processing Record 28 of Set 7 | hagonoy
# Processing Record 29 of Set 7 | avera
# Processing Record 30 of Set 7 | kjollefjord
# Processing Record 31 of Set 7 | kalmunai
# Processing Record 32 of Set 7 | makakilo city
# Processing Record 33 of Set 7 | inuvik
# Processing Record 34 of Set 7 | mogadishu
# Processing Record 35 of Set 7 | sile
# Processing Record 36 of Set 7 | aksay
# Processing Record 37 of Set 7 | iranshahr
# Processing Record 38 of Set 7 | tura
# Processing Record 39 of Set 7 | chumikan
# Processing Record 40 of Set 7 | derzhavinsk
# Processing Record 41 of Set 7 | cocobeach
# Processing Record 42 of Set 7 | yulara
# Processing Record 43 of Set 7 | jalu
# Processing Record 44 of Set 7 | dubovyy umet
# Processing Record 45 of Set 7 | atambua
# Processing Record 46 of Set 7 | cidreira
# Processing Record 47 of Set 7 | wiarton
# Processing Record 48 of Set 7 | seymchan
# Processing Record 49 of Set 7 | saint-pierre
# Processing Record 50 of Set 7 | ninohe
# Processing Record 1 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 8 | mocorito
# Processing Record 3 of Set 8 | carbondale
# Processing Record 4 of Set 8 | baghdad
# Processing Record 5 of Set 8 | novomichurinsk
# Processing Record 6 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 8 | ketchikan
# Processing Record 8 of Set 8 | lasa
# Processing Record 9 of Set 8 | valdivia
# Processing Record 10 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 8 | beringovskiy
# Processing Record 12 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 8 | carndonagh
# Processing Record 14 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 8 | weligama
# Processing Record 16 of Set 8 | trelew
# Processing Record 17 of Set 8 | mulege
# Processing Record 18 of Set 8 | udachnyy
# Processing Record 19 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 8 | cockburn town
# Processing Record 21 of Set 8 | sobolevo
# Processing Record 22 of Set 8 | ahuimanu
# Processing Record 23 of Set 8 | soto
# Processing Record 24 of Set 8 | bubaque
# Processing Record 25 of Set 8 | sao joao da barra
# Processing Record 26 of Set 8 | gisborne
# Processing Record 27 of Set 8 | raudeberg
# Processing Record 28 of Set 8 | asfi
# Processing Record 29 of Set 8 | ivybridge
# Processing Record 30 of Set 8 | camargo
# Processing Record 31 of Set 8 | perth
# Processing Record 32 of Set 8 | seoul
# Processing Record 33 of Set 8 | hailin
# Processing Record 34 of Set 8 | buala
# Processing Record 35 of Set 8 | sayyan
# Processing Record 36 of Set 8 | saleilua
# City not found. Skipping...
# Processing Record 37 of Set 8 | ostrovnoy
# Processing Record 38 of Set 8 | bouca
# Processing Record 39 of Set 8 | saint-leu
# Processing Record 40 of Set 8 | riobamba
# Processing Record 41 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 8 | saint-georges
# Processing Record 43 of Set 8 | severo-kurilsk
# Processing Record 44 of Set 8 | keuruu
# Processing Record 45 of Set 8 | tigil
# Processing Record 46 of Set 8 | coolum beach
# Processing Record 47 of Set 8 | nahariyya
# Processing Record 48 of Set 8 | roma
# Processing Record 49 of Set 8 | gobabis
# Processing Record 50 of Set 8 | binga
# Processing Record 1 of Set 9 | east linton
# Processing Record 2 of Set 9 | puerto escondido
# Processing Record 3 of Set 9 | alta floresta
# Processing Record 4 of Set 9 | antofagasta
# Processing Record 5 of Set 9 | camacha
# Processing Record 6 of Set 9 | weinan
# Processing Record 7 of Set 9 | ahipara
# Processing Record 8 of Set 9 | tafresh
# Processing Record 9 of Set 9 | lichinga
# Processing Record 10 of Set 9 | belaya gora
# Processing Record 11 of Set 9 | rundu
# Processing Record 12 of Set 9 | tingi
# Processing Record 13 of Set 9 | oranjemund
# Processing Record 14 of Set 9 | chernyshevskiy
# Processing Record 15 of Set 9 | kvareli
# Processing Record 16 of Set 9 | kaitangata
# Processing Record 17 of Set 9 | daud khel
# Processing Record 18 of Set 9 | bend
# Processing Record 19 of Set 9 | nieuw amsterdam
# Processing Record 20 of Set 9 | talakan
# Processing Record 21 of Set 9 | charleville-mezieres
# Processing Record 22 of Set 9 | marienburg
# Processing Record 23 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 24 of Set 9 | atbasar
# Processing Record 25 of Set 9 | eenhana
# Processing Record 26 of Set 9 | northam
# Processing Record 27 of Set 9 | christchurch
# Processing Record 28 of Set 9 | bangkal
# Processing Record 29 of Set 9 | ndele
# Processing Record 30 of Set 9 | sangar
# Processing Record 31 of Set 9 | havelock
# Processing Record 32 of Set 9 | kaeo
# Processing Record 33 of Set 9 | antalaha
# Processing Record 34 of Set 9 | ryotsu
# Processing Record 35 of Set 9 | batagay-alyta
# Processing Record 36 of Set 9 | anadyr
# Processing Record 37 of Set 9 | kemin
# Processing Record 38 of Set 9 | plouzane
# Processing Record 39 of Set 9 | weatherford
# Processing Record 40 of Set 9 | santa cruz
# Processing Record 41 of Set 9 | puerto penasco
# Processing Record 42 of Set 9 | bathsheba
# Processing Record 43 of Set 9 | nueve de julio
# Processing Record 44 of Set 9 | kungurtug
# Processing Record 45 of Set 9 | birao
# Processing Record 46 of Set 9 | solnechnyy
# Processing Record 47 of Set 9 | makokou
# Processing Record 48 of Set 9 | kununurra
# Processing Record 49 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 9 | tombouctou
# Processing Record 1 of Set 10 | say
# Processing Record 2 of Set 10 | xifeng
# Processing Record 3 of Set 10 | marsh harbour
# Processing Record 4 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 10 | coihaique
# Processing Record 6 of Set 10 | porto belo
# Processing Record 7 of Set 10 | grindavik
# Processing Record 8 of Set 10 | mount gambier
# Processing Record 9 of Set 10 | liverpool
# Processing Record 10 of Set 10 | grajau
# Processing Record 11 of Set 10 | amurzet
# Processing Record 12 of Set 10 | sabzevar
# Processing Record 13 of Set 10 | honiara
# Processing Record 14 of Set 10 | pochutla
# Processing Record 15 of Set 10 | jeremie
# Processing Record 16 of Set 10 | manokwari
# Processing Record 17 of Set 10 | pisco
# Processing Record 18 of Set 10 | port hedland
# Processing Record 19 of Set 10 | tamandare
# Processing Record 20 of Set 10 | rucheng
# Processing Record 21 of Set 10 | payakumbuh
# Processing Record 22 of Set 10 | ponta pora
# Processing Record 23 of Set 10 | oistins
# Processing Record 24 of Set 10 | minot
# Processing Record 25 of Set 10 | luderitz
# Processing Record 26 of Set 10 | igarka
# Processing Record 27 of Set 10 | korce
# Processing Record 28 of Set 10 | humboldt
# Processing Record 29 of Set 10 | yelizovo
# Processing Record 30 of Set 10 | loanda
# Processing Record 31 of Set 10 | majene
# Processing Record 32 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 10 | hami
# Processing Record 34 of Set 10 | chapais
# Processing Record 35 of Set 10 | vanavara
# Processing Record 36 of Set 10 | iqaluit
# Processing Record 37 of Set 10 | korla
# Processing Record 38 of Set 10 | trincomalee
# Processing Record 39 of Set 10 | longyearbyen
# Processing Record 40 of Set 10 | te anau
# Processing Record 41 of Set 10 | presidencia roque saenz pena
# Processing Record 42 of Set 10 | kiama
# Processing Record 43 of Set 10 | dakoro
# Processing Record 44 of Set 10 | vallenar
# Processing Record 45 of Set 10 | lincoln
# Processing Record 46 of Set 10 | staryy nadym
# Processing Record 47 of Set 10 | vilhena
# Processing Record 48 of Set 10 | monze
# Processing Record 49 of Set 10 | atasu
# Processing Record 50 of Set 10 | high rock
# Processing Record 1 of Set 11 | thinadhoo
# Processing Record 2 of Set 11 | bensonville
# Processing Record 3 of Set 11 | sibenik
# Processing Record 4 of Set 11 | uyuni
# Processing Record 5 of Set 11 | port blair
# Processing Record 6 of Set 11 | jacareacanga
# Processing Record 7 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 11 | nanga eboko
# Processing Record 9 of Set 11 | mococa
# Processing Record 10 of Set 11 | iralaya
# Processing Record 11 of Set 11 | harper
# Processing Record 12 of Set 11 | adeje
# Processing Record 13 of Set 11 | phan thiet
# Processing Record 14 of Set 11 | puerto montt
# Processing Record 15 of Set 11 | bonavista
# Processing Record 16 of Set 11 | kudahuvadhoo
# Processing Record 17 of Set 11 | hukuntsi
# Processing Record 18 of Set 11 | lengshuijiang
# Processing Record 19 of Set 11 | praia
# Processing Record 20 of Set 11 | virginia beach
# Processing Record 21 of Set 11 | tonekabon
# Processing Record 22 of Set 11 | constitucion
# Processing Record 23 of Set 11 | aguimes
# Processing Record 24 of Set 11 | san rafael
# Processing Record 25 of Set 11 | cuiluan
# Processing Record 26 of Set 11 | magdagachi
# Processing Record 27 of Set 11 | lillesand
# Processing Record 28 of Set 11 | nioro
# Processing Record 29 of Set 11 | skibbereen
# Processing Record 30 of Set 11 | conceicao do araguaia
# Processing Record 31 of Set 11 | sopelana
# Processing Record 32 of Set 11 | jiblah
# Processing Record 33 of Set 11 | sao felix do xingu
# Processing Record 34 of Set 11 | ca mau
# Processing Record 35 of Set 11 | moron
# Processing Record 36 of Set 11 | beloha
# Processing Record 37 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 11 | vila velha
# Processing Record 39 of Set 11 | tayga
# Processing Record 40 of Set 11 | acapulco
# Processing Record 41 of Set 11 | manaure
# Processing Record 42 of Set 11 | alingsas
# Processing Record 43 of Set 11 | belmonte
# Processing Record 44 of Set 11 | narsaq
# Processing Record 45 of Set 11 | tefe
# Processing Record 46 of Set 11 | acarau
# Processing Record 47 of Set 11 | camacupa
# Processing Record 48 of Set 11 | antsohihy
# Processing Record 49 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 50 of Set 11 | hammerfest
# Processing Record 1 of Set 12 | salinopolis
# Processing Record 2 of Set 12 | ixtapa
# Processing Record 3 of Set 12 | doka
# Processing Record 4 of Set 12 | rabat
# Processing Record 5 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 7 of Set 12 | puerto suarez
# Processing Record 8 of Set 12 | labuhan
# Processing Record 9 of Set 12 | pyaozerskiy
# Processing Record 10 of Set 12 | waiouru
# Processing Record 11 of Set 12 | warmbad
# Processing Record 12 of Set 12 | mwanza
# Processing Record 13 of Set 12 | hobyo
# Processing Record 14 of Set 12 | hun
# Processing Record 15 of Set 12 | berlevag
# Processing Record 16 of Set 12 | ruwi
# Processing Record 17 of Set 12 | yantikovo
# Processing Record 18 of Set 12 | staroaleyskoye
# Processing Record 19 of Set 12 | talnakh
# Processing Record 20 of Set 12 | carauari
# Processing Record 21 of Set 12 | hamilton
# Processing Record 22 of Set 12 | rogers
# Processing Record 23 of Set 12 | port augusta
# Processing Record 24 of Set 12 | bereda
# Processing Record 25 of Set 12 | kologriv
# Processing Record 26 of Set 12 | fez
# Processing Record 27 of Set 12 | zyryanka
# Processing Record 28 of Set 12 | lancaster
# Processing Record 29 of Set 12 | ust-ishim
# Processing Record 30 of Set 12 | merritt
# Processing Record 31 of Set 12 | lubango
# Processing Record 32 of Set 12 | nisia floresta
# Processing Record 33 of Set 12 | sochi
# Processing Record 34 of Set 12 | komsomolskiy
# Processing Record 35 of Set 12 | stony plain
# Processing Record 36 of Set 12 | swift current
# Processing Record 37 of Set 12 | kotturu
# Processing Record 38 of Set 12 | keansburg
# Processing Record 39 of Set 12 | micheldorf
# Processing Record 40 of Set 12 | port-cartier
# Processing Record 41 of Set 12 | damara
# Processing Record 42 of Set 12 | san marcos
# Processing Record 43 of Set 12 | banda aceh
# Processing Record 44 of Set 12 | naze
# Processing Record 45 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 46 of Set 12 | aktau
# Processing Record 47 of Set 12 | salou
# Processing Record 48 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 50 of Set 12 | hamamatsu
# Processing Record 1 of Set 13 | shenjiamen
# Processing Record 2 of Set 13 | mattoon
# Processing Record 3 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 13 | balassagyarmat
# Processing Record 5 of Set 13 | hille
# Processing Record 6 of Set 13 | kochki
# Processing Record 7 of Set 13 | srednekolymsk
# Processing Record 8 of Set 13 | blatnica
# Processing Record 9 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 13 | newport
# Processing Record 11 of Set 13 | gravdal
# Processing Record 12 of Set 13 | vao
# Processing Record 13 of Set 13 | tocopilla
# Processing Record 14 of Set 13 | portland
# Processing Record 15 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 13 | juneau
# Processing Record 17 of Set 13 | muriae
# Processing Record 18 of Set 13 | bulaevo
# Processing Record 19 of Set 13 | el alto
# Processing Record 20 of Set 13 | kabalo
# Processing Record 21 of Set 13 | bazaliya
# Processing Record 22 of Set 13 | acajutla
# Processing Record 23 of Set 13 | muroto
# Processing Record 24 of Set 13 | bure
# Processing Record 25 of Set 13 | souris
# Processing Record 26 of Set 13 | broken hill
# Processing Record 27 of Set 13 | imisli
# City not found. Skipping...
# Processing Record 28 of Set 13 | kilindoni
# Processing Record 29 of Set 13 | sikonge
# Processing Record 30 of Set 13 | dighwara
# Processing Record 31 of Set 13 | plettenberg bay
# Processing Record 32 of Set 13 | hassleholm
# Processing Record 33 of Set 13 | papayal
# Processing Record 34 of Set 13 | chhatak
# Processing Record 35 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 13 | pyay

# %%
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv(path_or_buf='/Users/Upama/Documents/Data Analytics Class Work/Challenge#6/WeatherPy_Database.csv', index_label='City_ID')
challenge_city_data_df
